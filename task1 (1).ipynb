# %%
# Step 1: Import pandas and load the dataset
import pandas as pd

# Load the CSV file
df = pd.read_csv("netflix_titles_nov_2019.csv")

# Display the first few rows
df.head()
# Out:
#     show_id                                title                    director  \
# 0  81193313                            Chocolate                         NaN
# 1  81197050  Guatemala: Heart of the Mayan World  Luis Ara, Ignacio Jaunsolo
# 2  81213894                      The Zoya Factor             Abhishek Sharma
# 3  81082007                            Atlantics                   Mati Diop
# 4  80213643                      Chip and Potato                         NaN
#
#                                                 cast  \
# 0  Ha Ji-won, Yoon Kye-sang, Jang Seung-jo, Kang ...
# 1                                  Christian Morales
# 2  Sonam Kapoor, Dulquer Salmaan, Sanjay Kapoor, ...
# 3  Mama Sane, Amadou Mbow, Ibrahima Traore, Nicol...
# 4  Abigail Oliver, Andrea Libman, Briana Buckmast...
#
#                     country         date_added  release_year rating  \
# 0               South Korea  November 30, 2019          2019  TV-14
# 1                       NaN  November 30, 2019          2019   TV-G
# 2                     India  November 30, 2019          2019  TV-14
# 3  France, Senegal, Belgium  November 29, 2019          2019  TV-14
# 4    Canada, United Kingdom                NaN          2019   TV-Y
#
#     duration                                          listed_in  \
# 0   1 Season  International TV Shows, Korean TV Shows, Roman...
# 1     67 min                Documentaries, International Movies
# 2    135 min             Comedies, Dramas, International Movies
# 3    106 min   Dramas, Independent Movies, International Movies
# 4  2 Seasons                                           Kids' TV
#
#                                          description     type
# 0  Brought together by meaningful meals in the pa...  TV Show
# 1  From Sierra de las Minas to Esquipulas, explor...    Movie
# 2  A goofy copywriter unwittingly convinces the I...    Movie
# 3  Arranged to marry a rich man, young Ada is cru...    Movie
# 4  Lovable pug Chip starts kindergarten, makes ne...  TV Show

# %%
# Step 2: Identify and handle missing values

# Check for missing values
print("Missing values before handling:")
print(df.isnull().sum())

# Fill missing values with 'Unknown'
df.fillna('Unknown', inplace=True)

# Confirm missing values handled
print("\nMissing values after handling:")
print(df.isnull().sum())
# Out:
# Missing values before handling:
# show_id            0
# title              0
# director        1901
# cast             556
# country          427
# date_added       642
# release_year       0
# rating            10
# duration           0
# listed_in          0
# description        0
# type               0
# dtype: int64
#
# Missing values after handling:
# show_id         0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# type            0
# dtype: int64

# %%
# Step 3: Remove duplicate rows

# Check for duplicates
print("Number of duplicate rows:", df.duplicated().sum())

# Drop duplicate rows
df = df.drop_duplicates()

# Confirm duplicates removed
print("Duplicate rows after removal:", df.duplicated().sum())
# Out:
# Number of duplicate rows: 0
# Duplicate rows after removal: 0

# %%
# Step 4: Standardize text values (e.g., countries)

# Convert to lowercase and strip whitespace
df['country'] = df['country'].str.lower().str.strip()

# Replace inconsistent names (example)
df['country'] = df['country'].replace({
    'united states': 'usa',
    'united kingdom': 'uk'
})

# View unique countries
print("Unique countries (after standardization):")
print(df['country'].unique())
# Out:
# Unique countries (after standardization):
# ['south korea' 'unknown' 'india' 'france, senegal, belgium'
#  'canada, united kingdom' 'nigeria' 'france' 'south africa'
#  'united states, spain, colombia, mexico' 'usa' 'japan' 'brazil'
#  'germany, canada, united states' 'canada, norway' 'poland' 'mexico'
#  'china' 'united states, united arab emirates' 'united states, japan'
#  'spain' 'singapore, united states' 'united states, canada'
#  'united kingdom, germany, canada, united states' 'australia, france'
#  'germany' 'germany, united kingdom' 'italy, united states'
#  'united states, new zealand, united kingdom'
#  'united kingdom, germany, united states' 'united states, germany'
#  'argentina' 'taiwan' 'united kingdom, united states'
#  'finland, germany, belgium' 'united kingdom, france'
#  'united states, spain, chile, peru' 'colombia' 'united states, ireland'
#  'india, united states' 'thailand' 'turkey'
#  'argentina, united states, mexico' 'uk'
#  'united states, united kingdom, canada' 'china, hong kong'
#  'canada, united states' 'canada'
#  'south africa, united states, new zealand, canada'
#  'united states, australia, mexico' 'united states, south korea, japan'
#  'australia' 'united states, italy, united kingdom, liechtenstein'
#  'hong kong, united states' 'italy' 'united states, united kingdom, italy'
#  'united states, france, canada, spain' 'mexico, united states'
#  'united states, mexico' 'united states, united kingdom' 'hong kong'
#  'canada, australia' 'united states, australia' 'italy, belgium, france'
#  'argentina, spain' 'united states, united kingdom, france'
#  'israel, united states' 'united states, united kingdom, germany'
#  'switzerland' 'russia' 'singapore, malaysia' 'canada, luxembourg'
#  'hong kong, china' 'united states, spain, germany'
#  'egypt, austria, united states' 'belgium, luxembourg, france'
#  'netherlands' 'indonesia' 'united states, china'
#  'united kingdom, poland, united states' 'united states, czech republic'
#  'spain, france' 'australia, united states' 'united kingdom, hong kong'
#  'united kingdom, canada' 'denmark, france, poland'
#  'united states, germany, canada' 'poland,'
#  'united states, united kingdom, australia' 'poland, west germany'
#  'germany, united states' 'united kingdom, france, united states' 'peru'
#  'united states, malta, united kingdom'
#  'denmark, france, italy, belgium, netherlands' 'vietnam' 'france, canada'
#  'united kingdom, france, germany, spain'
#  'france, switzerland, spain, united states, united arab emirates'
#  'canada, united states, united kingdom' 'japan, canada, south korea'
#  'united states, india, south korea, china' 'pakistan'
#  'brazil, united states' 'united kingdom, canada, united states'
#  'united states, france' 'germany, united states, canada'
#  'denmark, brazil, france, portugal, sweden' 'france, united states'
#  'united arab emirates' 'egypt' 'china, united kingdom' 'chile'
#  'china, taiwan'
#  'israel, germany, poland, luxembourg, belgium, france, united states'
#  'india, turkey' 'philippines' 'united states, italy'
#  'south korea, united states' 'lebanon' 'malaysia, singapore, hong kong'
#  'france, south korea, japan' 'bulgaria, united states'
#  'united kingdom, south korea' 'united states, germany, australia'
#  'singapore, japan, france' 'united kingdom, poland'
#  'philippines, singapore' 'france, belgium' 'united kingdom, germany'
#  'australia, canada' 'sweden' 'taiwan, china, france, united states'
#  'germany, italy' 'italy, france, switzerland'
#  'china, hong kong, united states'
#  'germany, united kingdom, united states'
#  'united states, czech republic, united kingdom' 'united states, spain'
#  'dominican republic' 'canada, united kingdom, united states' 'israel'
#  'thailand, china, united states' 'argentina, united states' 'new zealand'
#  'germany, united states, sweden' 'sweden, united states' 'belgium'
#  'lebanon, jordan' 'malaysia' 'uruguay, spain, mexico'
#  'france, luxembourg, canada' 'spain, france, italy'
#  'united states, india, bangladesh' 'germany, belgium'
#  'canada, france, italy, morocco, united states'
#  'denmark, germany, belgium, united kingdom, france'
#  'italy, canada, france' 'thailand, united states'
#  'canada, germany, south africa' 'united states, nicaragua'
#  'south korea, china, united states' 'belgium, france'
#  'united kingdom, india, sweden' 'india, soviet union' 'canada, france'
#  'india, mexico' 'georgia, germany, france' 'india, switzerland'
#  'united states, south korea, china' 'united arab emirates, romania'
#  'spain, belgium, switzerland, united states, china, united kingdom'
#  'pakistan, united states' 'canada, india' 'india, canada' 'venezuela'
#  'australia, india' 'india, malaysia'
#  'canada, india, thailand, united states, united arab emirates'
#  'germany, jordan, netherlands' 'turkey, france, germany, poland'
#  'saudi arabia' 'china, india, nepal' 'france, canada, belgium'
#  'australia, new zealand, united states' 'united states, brazil'
#  'canada, ireland, united states'
#  'united states, france, canada, lebanon, qatar' 'switzerland, france'
#  'france, united kingdom, united states' 'france, united kingdom'
#  'norway, germany' 'united kingdom, canada, japan'
#  'ireland, united kingdom' 'france, morocco' 'spain, argentina'
#  'cambodia, united states' 'united states, denmark'
#  'bulgaria, united states, spain, canada'
#  'united states, united kingdom, denmark, sweden'
#  'netherlands, belgium, united kingdom, united states'
#  'united states, uruguay' 'czech republic, france'
#  'united states, senegal' 'united states, colombia, mexico'
#  'united states, hong kong'
#  'united kingdom, italy, israel, peru, united states'
#  'argentina, uruguay, spain, france' 'germany, united states, italy'
#  'canada, spain' 'italy, germany'
#  'australia, armenia, japan, jordan, mexico, mongolia, new zealand, philippines, south africa, sweden, united states, uruguay'
#  'united states, argentina' 'france, china, canada'
#  'united kingdom, france, belgium, united states' 'spain, germany'
#  'germany, united states, hong kong, singapore' 'chile, france'
#  'slovenia, croatia, germany, czech republic, qatar'
#  'russia, united states' 'chile, argentina, france, spain, united states'
#  'netherlands, united states' 'united states, iceland'
#  'united states, canada, japan, panama'
#  'israel, sweden, germany, netherlands'
#  'united kingdom, france, canada, belgium, united states'
#  'finland, sweden, norway, latvia, germany'
#  'france, united kingdom, india' 'united kingdom, israel, russia'
#  'united kingdom, south africa' 'czech republic, slovakia'
#  'spain, france, uruguay' 'colombia, united states' 'singapore, france'
#  'united states, australia, samoa, united kingdom' 'spain, switzerland'
#  'united states, australia, china' 'south africa, united states, germany'
#  'united kingdom, singapore' 'netherlands, belgium'
#  'united kingdom, russia'
#  'brazil, netherlands, united states, colombia, austria, germany'
#  'united states, botswana' 'india, germany' 'portugal, spain'
#  'denmark, united kingdom, south africa, sweden, belgium'
#  'germany, sri lanka' 'spain, italy, argentina'
#  'chile, spain, argentina, germany' 'france, germany, switzerland'
#  'west germany' 'italy, india' 'belgium, india, australia'
#  'china, south korea, united states' 'united kingdom, spain, belgium'
#  'ireland, united kingdom, italy, united states' 'austria, czech republic'
#  'united states, greece, brazil' 'lebanon, qatar'
#  'united kingdom, jordan, qatar, iran' 'norway, denmark, sweden'
#  'netherlands, germany, italy, canada'
#  'belgium, ireland, netherlands, germany, afghanistan'
#  'united states, venezuela' 'turkey, azerbaijan' 'israel, germany, france'
#  'brazil, canada' 'canada, japan, netherlands' 'spain, cuba'
#  'united states, hungary' 'france, germany' 'united states, kazakhstan'
#  'peru, united states, united kingdom' 'france, qatar'
#  'united kingdom, australia, canada, united states'
#  'united kingdom, germany, canada' 'netherlands, denmark, south africa'
#  'ireland, south africa' 'united states, russia'
#  'chile, united states, france' 'united states, greece, united kingdom'
#  'pakistan, norway, united states' 'france, belgium, spain'
#  'argentina, chile, peru' 'denmark, united kingdom'
#  'india, united kingdom' 'croatia, slovenia, serbia, montenegro'
#  'mexico, france' 'denmark, zimbabwe'
#  'china, germany, india, united states' 'united arab emirates, jordan'
#  'china, united states'
#  'denmark, indonesia, finland, norway, united kingdom, israel, france, united states, germany, netherlands'
#  'united kingdom, united states, spain, germany, greece, canada'
#  'united states, france, japan' 'canada, united kingdom, netherlands'
#  'united states, new zealand, japan'
#  'united states, netherlands, japan, france'
#  'france, united states, canada' 'australia, france, ireland'
#  'united kingdom, ukraine, united states'
#  'norway, united kingdom, france, ireland'
#  'united kingdom, united states, greece, italy, germany'
#  'australia, united kingdom, united states, new zealand, italy, france'
#  'norway, united states' 'united kingdom,'
#  'united states, bermuda, ecuador'
#  'united states, hungary, ireland, canada'
#  'united kingdom, egypt, united states' 'spain, mexico, france']

# %%
# Step 5: Convert date formats to a consistent type

# Convert 'date_added' to datetime format
df['date_added'] = pd.to_datetime(df['date_added'], errors='coerce')

# Check for conversion issues
print("Null values in 'date_added' after conversion:", df['date_added'].isnull().sum())
# Out:
# Null values in 'date_added' after conversion: 642

# %%
# Step 6: Rename column headers (lowercase and underscores)

df.columns = df.columns.str.lower().str.replace(' ', '_')

# Confirm column names
print("Cleaned column headers:")
print(df.columns)
# Out:
# Cleaned column headers:
# Index(['show_id', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description',
#        'type'],
#       dtype='object')

# %%
# Step 7: Check and fix data types

# View data types
print("Data types before conversion:")
print(df.dtypes)

# Convert 'release_year' to integer
df['release_year'] = pd.to_numeric(df['release_year'], errors='coerce')

# View data types again
print("Data types after conversion:")
print(df.dtypes)
# Out:
# Data types before conversion:
# show_id                  int64
# title                   object
# director                object
# cast                    object
# country                 object
# date_added      datetime64[ns]
# release_year             int64
# rating                  object
# duration                object
# listed_in               object
# description             object
# type                    object
# dtype: object
# Data types after conversion:
# show_id                  int64
# title                   object
# director                object
# cast                    object
# country                 object
# date_added      datetime64[ns]
# release_year             int64
# rating                  object
# duration                object
# listed_in               object
# description             object
# type                    object
# dtype: object

# %%
# Final Step: Save the cleaned dataset to a new CSV

df.to_csv("cleaned_netflix_titles.csv", index=False)
print("Cleaned dataset saved as 'cleaned_netflix_titles.csv'")
# Out:
# Cleaned dataset saved as 'cleaned_netflix_titles.csv'
